# %% [markdown]
# # Dataset: African American Poetry
#
# The [**African American Periodical Poetry** dataset](https://www.responsible-datasets-in-context.com/posts/african-american-periodical-poetry/aa-periodical-poetry.html) contains information about poems published in African American periodicals. Key columns in the dataset include:
#
# ### Description of Columns in the Dataset:
#
# 1. **title**:
#    The title of the poem.
# 2. **author (first last)**:
#    The full name of the author, in the format of "first name last name."
# 3. **author (last name)**:
#    The last name of the author.
# 4. **text**:
#    The full text of the poem.
# 5. **month**:
#    The month when the poem was published.
# 6. **year**:
#    The year when the poem was published.
# 7. **venue**:
#    The primary venue or periodical where the poem was published.
# 8. **edited by**:
#    The name of the editor or the person responsible for editing the publication in which the poem appeared.
# 9. **form (if known)**:
#    The poetic form used in the poem, if it is known (e.g., "Elegy", "Common Measure").
# 10. **gender (if known)**:
#     The gender of the poet, if known ("male" or "female").
# 11. **themes**:
#     A list of themes present in the poem, which may include multiple themes separated by commas (e.g., "Spanish-American War, Empire").
# 12. **second venue**:
#     A secondary venue where the poem may have been published, if applicable.
# 13. **published in (city)**:
#     The city where the poem was published.
# 14. **Magazine Type**:
#     Indicates the type of magazine, such as "Predom. Black" for predominantly Black magazines.
# 15. **Author Bio.**:
#     A link to the author’s biography or a brief note about their life.
#
# This dataset captures details about poems written by African-American poets between 1900 and 1928, including metadata on publication, themes, and author information.
#
# This dataset can be used to explore trends in African American poetry, analyze poem lengths, publication patterns, and compare characteristics of poets across periodicals. It is especially valuable for historical and cultural analysis in the [digital humanities](https://en.wikipedia.org/wiki/Digital_humanities).

# %%
# load the dataset

import pandas as pd
aap = pd.read_csv("https://raw.githubusercontent.com/melaniewalsh/responsible-datasets-in-context/main/datasets/aa-periodical-poetry/African-American-Periodical-Poetry_1900-1928-Created-by-Amardeep-Singh-and-Kate-Hennessey,-Lehigh-University.csv")
aap.head()
# Out:
#                               title        author (first last)  \
# 0                          New Wars  Benjamin Griffith Brawley
# 1                         A Picture     Olivia Ward Bush-Banks
# 2             The Christmas Reunion         Augustus M. Hodges
# 3  A Memorial of Frederick Douglass            C. Henry Holmes
# 4                 The Negro's Worth       Alonzo Milton Skrine
#
#   author (last name)                                               text  \
# 0            Brawley  HURL on the lance! Break up the ancient peace!...
# 1         Bush-Banks  I drew a picture long ago —\nA picture of a su...
# 2             Hodges  Twas a bright Christmas morning in "Ole Kentuc...
# 3             Holmes  He was a noble hero, born in an humble state,\...
# 4             Skrine  Who casts a slur on Negro worth, a stain on Ne...
#
#        month  year              venue          edited by form (if known)  \
# 0   November  1900  Colored American   Walter W. Wallace  Common Measure
# 1       June  1900  Colored American   Walter W. Wallace  Common Measure
# 2   December  1900  Colored American   Walter W. Wallace             NaN
# 3  September  1900  Colored American   Walter W. Wallace           Elegy
# 4   December  1900  Colored American   Walter W. Wallace             NaN
#
#   gender (if known)                                             themes  \
# 0              male                       Spanish-American War, Empire
# 1            female                                                NaN
# 2              male                                            Slavery
# 3              male                                 Frederick Douglass
# 4              male  Civil War, Spanish-American War, Labor, Slaver...
#
#   second venue published in (city)  Magazine Type  \
# 0          NaN              Boston  Predom. Black
# 1          NaN              Boston  Predom. Black
# 2          NaN              Boston  Predom. Black
# 3          NaN              Boston  Predom. Black
# 4          NaN              Boston  Predom. Black
#
#                                          Author Bio.
# 0  https://en.wikipedia.org/wiki/Benjamin_Griffit...
# 1  https://en.wikipedia.org/wiki/Olivia_Ward_Bush...
# 2   https://en.wikipedia.org/wiki/Augustus_M._Hodges
# 3                                                NaN
# 4  https://scalar.lehigh.edu/african-american-poe...

# %% [markdown]
# # Wrangling

# %% [markdown]
# **📝 Exercise 1**: Create a new column `Poem_Length` that calculates the length of each poem (number of words or characters).

# %%
aap['Poem_Length'] = aap['text'].apply(lambda x: len(str(x).split()))
aap.head()
# Out:
#                               title        author (first last)  \
# 0                          New Wars  Benjamin Griffith Brawley
# 1                         A Picture     Olivia Ward Bush-Banks
# 2             The Christmas Reunion         Augustus M. Hodges
# 3  A Memorial of Frederick Douglass            C. Henry Holmes
# 4                 The Negro's Worth       Alonzo Milton Skrine
#
#   author (last name)                                               text  \
# 0            Brawley  HURL on the lance! Break up the ancient peace!...
# 1         Bush-Banks  I drew a picture long ago —\nA picture of a su...
# 2             Hodges  Twas a bright Christmas morning in "Ole Kentuc...
# 3             Holmes  He was a noble hero, born in an humble state,\...
# 4             Skrine  Who casts a slur on Negro worth, a stain on Ne...
#
#        month  year              venue          edited by form (if known)  \
# 0   November  1900  Colored American   Walter W. Wallace  Common Measure
# 1       June  1900  Colored American   Walter W. Wallace  Common Measure
# 2   December  1900  Colored American   Walter W. Wallace             NaN
# 3  September  1900  Colored American   Walter W. Wallace           Elegy
# 4   December  1900  Colored American   Walter W. Wallace             NaN
#
#   gender (if known)                                             themes  \
# 0              male                       Spanish-American War, Empire
# 1            female                                                NaN
# 2              male                                            Slavery
# 3              male                                 Frederick Douglass
# 4              male  Civil War, Spanish-American War, Labor, Slaver...
#
#   second venue published in (city)  Magazine Type  \
# 0          NaN              Boston  Predom. Black
# 1          NaN              Boston  Predom. Black
# 2          NaN              Boston  Predom. Black
# 3          NaN              Boston  Predom. Black
# 4          NaN              Boston  Predom. Black
#
#                                          Author Bio.  Poem_Length
# 0  https://en.wikipedia.org/wiki/Benjamin_Griffit...          266
# 1  https://en.wikipedia.org/wiki/Olivia_Ward_Bush...          254
# 2   https://en.wikipedia.org/wiki/Augustus_M._Hodges          835
# 3                                                NaN          199
# 4  https://scalar.lehigh.edu/african-american-poe...          280

# %% [markdown]
# **📝 Exercise 2**: Create a new dataframe `poems_themes` which "explodes" the column `themes`. Each poem can then contain multiple rows for its different themes.
#
# *Attention*: split by ", " (a comma + a space), otherwise, if you just use a comma, you would get two categories like "Religion" and " Religion"

# %%
poems_themes = aap.assign(themes=aap['themes'].str.split(', ')).explode('themes')
poems_themes.head()
# Out:
#                               title        author (first last)  \
# 0                          New Wars  Benjamin Griffith Brawley
# 0                          New Wars  Benjamin Griffith Brawley
# 1                         A Picture     Olivia Ward Bush-Banks
# 2             The Christmas Reunion         Augustus M. Hodges
# 3  A Memorial of Frederick Douglass            C. Henry Holmes
#
#   author (last name)                                               text  \
# 0            Brawley  HURL on the lance! Break up the ancient peace!...
# 0            Brawley  HURL on the lance! Break up the ancient peace!...
# 1         Bush-Banks  I drew a picture long ago —\nA picture of a su...
# 2             Hodges  Twas a bright Christmas morning in "Ole Kentuc...
# 3             Holmes  He was a noble hero, born in an humble state,\...
#
#        month  year              venue          edited by form (if known)  \
# 0   November  1900  Colored American   Walter W. Wallace  Common Measure
# 0   November  1900  Colored American   Walter W. Wallace  Common Measure
# 1       June  1900  Colored American   Walter W. Wallace  Common Measure
# 2   December  1900  Colored American   Walter W. Wallace             NaN
# 3  September  1900  Colored American   Walter W. Wallace           Elegy
#
#   gender (if known)                themes second venue published in (city)  \
# 0              male  Spanish-American War          NaN              Boston
# 0              male                Empire          NaN              Boston
# 1            female                   NaN          NaN              Boston
# 2              male               Slavery          NaN              Boston
# 3              male    Frederick Douglass          NaN              Boston
#
#    Magazine Type                                        Author Bio.  \
# 0  Predom. Black  https://en.wikipedia.org/wiki/Benjamin_Griffit...
# 0  Predom. Black  https://en.wikipedia.org/wiki/Benjamin_Griffit...
# 1  Predom. Black  https://en.wikipedia.org/wiki/Olivia_Ward_Bush...
# 2  Predom. Black   https://en.wikipedia.org/wiki/Augustus_M._Hodges
# 3  Predom. Black                                                NaN
#
#    Poem_Length
# 0          266
# 0          266
# 1          254
# 2          835
# 3          199

# %% [markdown]
# # Histograms

# %% [markdown]
# **📝 Exercise 3**: Using the dataframe `poems_themes`, plot a **histogram** showing its distribution of values. (i.e., how many times each theme is represented).
#
# (Tip: You can make a horizontal histogram by assigning the column to the y axis.
# Use `fig.update_yaxes(categoryorder='total ascending')` to sort the values.)

# %%
import plotly.express as px

fig = px.histogram(poems_themes, y='themes')
fig.update_yaxes(categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4dd09bf3-9865-4626-b230-749092f8dd9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dd09bf3-9865-4626-b230-749092f8dd9c")) {                    Plotly.newPlot(                        "4dd09bf3-9865-4626-b230-749092f8dd9c",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"count=%{x}\u003cbr\u003ethemes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"xaxis":"x","y":["Spanish-American War","Empire",null,"Slavery","Frederick Douglass","Civil War","Spanish-American War","Labor","Slavery","Progress and Racial Uplift","Lynching and Racialized Violence","Patriotism","Racism","Empire",null,null,null,null,null,null,null,null,null,null,"Intertext","Religion",null,"Slavery","AAVE","AAVE","Paul Laurence Dunbar","Patriotism","AAVE","Religion","AAVE","Religion","Religion","AAVE","AAVE","AAVE",null,null,null,"Slavery","Civil War","Motherhood",null,null,null,null,"Abraham Lincoln","Civil War",null,"Labor","Spanish-American War",null,null,"Intertext","Interracial",null,null,"Abraham Lincoln","Progress and Racial Uplift","Racism","","Religion",null,"Slavery Africa","Travel-Migration-Great Migration","Childhood",null,"Interracial","Black Beauty","Lynching and Racialized Violence",null,"Lynching and Racialized Violence","Intertext","Civil War","Abraham Lincoln","Slavery",null,null,"Scientific Racism","AAVE",null,null,"Africa","Ode","Race",null,"AAVE","Interracial",null,null,"Africa","Labor","Slavery","Religion","Intertext","Progress and Racial Uplift","Religion",null,"Religion","Labor","Progress and Racial Uplift","Racism","Slavery","Religion",null,null,null,null,"Empire","Slavery","Civil War",null,null,null,null,null,"AAVE","Slavery","Labor",null,null,null,"Lincoln","Civil War","Slavery",null,null,null,"Slavery","Labor","AAVE",null,"AAVE","Slavery",null,"AAVE","AAVE",null,null,null,null,"AAVE","Race","Progress-and-Racial Uplift",null,null,null,null,"AAVE",null,null,null,"Progress and Racial Uplift","Travel-Migration-Great Migration",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"Religion: the Black Church","Slavery",null,null,null,null,null,null,"Native American",null,"Progress and Racial Uplift","Civil War","Slavery","Progress and Racial Uplift","Progress and Racial Uplift","AAVE","Travel-Migration-Great Migration",null,"AAVE","Labor",null,"Intertext","Paul Laurence Dunbar",null,null,"Labor","Slavery",null,"Paul Laurence Dunbar","Lynching-and-Racialized-Violence","Intertext","Paul Laurence Dunbar",null,null,null,null,"Civil War","Patriotism",null,"AAVE","Paul Laurence Dunbar",null,null,null,null,"Ars Poetica",null,"Lynching-and-Racialized-Violence","Africa","Labor",null,null,null,null,null,null,"AAVE",null,null,null,null,null,null,"AAVE",null,null,null,null,null,"AAVE","Brownsville","Racism","Military",null,null,null,null,null,"Motherhood",null,"Progress-and-Racial Uplift","Racism","Racism","Childhood",null,null,null,null,"Religion: the Black Church",null,null,"Race","Intertext","Paul Laurence Dunbar","Empire","Racism","Intertext",null,null,null,"Motherhood","Childhood",null,null,"Civil War","Music","Patriotism","Slavery","Slavery","Africa",null,"AAVE","Intertext",null,"Travel-Migration-Great Migration","Caribbean","Caribbean","Interracial-Mixed Race",null,"Intertext",null,null,"Abraham Lincoln","Brownsville Affair","HBCU","Religion","Labor","Racism",null,"AAVE",null,null,null,"AAVE","Labor","Spanish-American War","Patriotism","Lynching and Racialized Violence",null,null,"Limerick",null,null,null,null,"Progress-and-Racia ...

# %% [markdown]
# **📝 Exercise 4**: Again, using the dataframe `poems_themes`, plot a **histogram** showing its distribution of values, but now group them by gender.

# %%
fig = px.histogram(poems_themes, y='themes', color='gender (if known)')
fig.update_yaxes(categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="155e138f-2687-40cc-a988-504ddc1d4f20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("155e138f-2687-40cc-a988-504ddc1d4f20")) {                    Plotly.newPlot(                        "155e138f-2687-40cc-a988-504ddc1d4f20",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"gender (if known)=male\u003cbr\u003ecount=%{x}\u003cbr\u003ethemes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"male","offsetgroup":"male","orientation":"h","showlegend":true,"xaxis":"x","y":["Spanish-American War","Empire","Slavery","Frederick Douglass","Civil War","Spanish-American War","Labor","Slavery","Progress and Racial Uplift","Lynching and Racialized Violence","Patriotism","Racism","Empire",null,null,null,null,null,null,null,null,null,"Intertext","Religion",null,"Slavery","AAVE","AAVE","Paul Laurence Dunbar","Patriotism","AAVE","Religion","AAVE","Religion","Religion","AAVE","AAVE","AAVE",null,null,null,"Slavery","Civil War","Motherhood",null,null,"Abraham Lincoln","Civil War",null,"Labor","Spanish-American War",null,"Intertext","Interracial",null,"Progress and Racial Uplift","Racism","","Religion","Slavery Africa","Travel-Migration-Great Migration",null,"Interracial","Black Beauty","Lynching and Racialized Violence",null,"Lynching and Racialized Violence","Intertext","Civil War","Abraham Lincoln","Slavery",null,"Scientific Racism","AAVE",null,null,"AAVE","Interracial",null,null,"Africa","Labor","Slavery","Religion","Intertext","Progress and Racial Uplift","Religion",null,"Religion","Labor","Progress and Racial Uplift","Racism","Slavery","Religion",null,null,null,null,"Empire","Slavery","Civil War",null,"AAVE","Slavery","Labor",null,null,"Lincoln","Civil War","Slavery",null,null,"Slavery","Labor","AAVE",null,"AAVE","Slavery",null,"AAVE","AAVE",null,null,null,null,"AAVE","Race","Progress-and-Racial Uplift",null,null,null,null,"AAVE",null,null,null,"Progress and Racial Uplift","Travel-Migration-Great Migration",null,null,null,null,null,null,null,"Religion: the Black Church","Slavery",null,null,"Native American","Progress and Racial Uplift","Progress and Racial Uplift","AAVE","Travel-Migration-Great Migration",null,"AAVE","Labor",null,"Intertext","Paul Laurence Dunbar",null,null,"Labor","Slavery","Paul Laurence Dunbar","Intertext","Paul Laurence Dunbar",null,null,null,"Civil War","Patriotism",null,"AAVE","Paul Laurence Dunbar",null,null,null,null,"Ars Poetica",null,"Lynching-and-Racialized-Violence","Africa","Labor",null,null,null,null,null,null,"AAVE",null,null,null,null,null,null,"AAVE",null,null,null,null,"Racism","Childhood",null,null,null,null,null,"Race","Intertext","Paul Laurence Dunbar","Empire","Racism","Intertext","Civil War","Music","Patriotism","Slavery",null,"AAVE","Intertext",null,"Travel-Migration-Great Migration","Caribbean","Caribbean","Interracial-Mixed Race",null,"Intertext",null,"Abraham Lincoln","Brownsville Affair","HBCU","Religion","Labor","Racism",null,"AAVE",null,null,null,"AAVE","Labor","Spanish-American War","Patriotism","Lynching and Racialized Violence",null,null,"Limerick",null,null,null,"Progress-and-Racial Uplift",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"Frederick Douglass",null,null,"Paul Laurence Dunbar",null,null,"Religion",null,null,"Progress and Racial Uplift","Booker T. Washington","",null,"Progress and Racial Uplift","Patriotism","Spanish-American War","Empire","Patriotism","Civil War",null,"Class","Religion","Science","Medicine","AAVE","Progress and Racial Uplift","Religion","Religion","Progress and Racial Uplift","Religion","Ars Poetica","Native American","H ...

# %% [markdown]
# **📝 Exercise 5**: Now, use the same plot as before, but show it:
# - as percentages (100% stacked) - use the argument `barnorm='percent'`
# - in horizontal position

# %%
fig = px.histogram(poems_themes, y='themes', color='gender (if known)', barnorm='percent')
fig.update_yaxes(categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928],"xaxis":"x","y":[327.6666666666667,214.08823529411765,282.3333333333333,263.3181818181818,250.25,147.66176470588235,154.24358974358975,183.6304347826087,158.75,214.25,542.4,153.8,115.2,326.0,169.42857142857142,308.0,164.94736842105263,83.0,166.0,102.0909090909091,74.4,121.5,107.53846153846153,90.6969696969697,80.28813559322033,117.96428571428571,96.55844155844156,114.20394736842105,121.55555555555556],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatt ...

# %% [markdown]
# # Scatter plot

# %% [markdown]
# **📝 Exercise 9**: Create a scatter plot where `Poem_Length` is mapped to point y-axis, `year` to x-axis, and another column like `venue` to point color.
# Experiment with changing the mappings to gain different insights.

# %%
fig = px.scatter(aap, x='year', y='Poem_Length', color='venue', title='Poem Length by Year and Venue')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ba71e4b7-dfdd-4532-8c39-e7f051ee34dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba71e4b7-dfdd-4532-8c39-e7f051ee34dc")) {                    Plotly.newPlot(                        "ba71e4b7-dfdd-4532-8c39-e7f051ee34dc",                        [{"hovertemplate":"venue=Colored American \u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Colored American ","orientation":"v","showlegend":true,"x":[1900,1900,1900,1900,1900,1900,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1902,1908,1908],"xaxis":"x","y":[266,254,835,199,280,132,233,177,117,148,100,121,255,496,1231,137,295,217,177,451,136,106,141,73,107,97,93],"yaxis":"y","type":"scatter"},{"hovertemplate":"venue=Colored American\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Colored American","orientation":"v","showlegend":true,"x":[1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1902,1902,1905,1905,1905,1908,1908,1908,1908,1908,1908,1908,1908,1908,1908,1909],"xaxis":"x","y":[99,500,130,47,75,98,115,122,328,366,196,190,118,116,84,84,252,625,391,108,104,101,121,139,501,113,117,232,123,128,140,67],"yaxis":"y","type":"scatter"},{"hovertemplate":"venue=Colored American Magazine\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American Magazine","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Colored American Magazine","orientation":"v","showlegend":true,"x":[1902,1902,1902,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1904,1904,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909],"xaxis":"x","y":[271,374,65,319,104,90,350,116,253,292,141,180,336,232,48,236,883,87,119,394,137,104,126,138,1108,70,103,73,50,69,91,75,82,114,105,112,162,375,114,170,507,270,189,372,402,413,45,128,198,196,117,39,171,191,79,184,109,116,335,256,183,154,122,137,104,120,83,413,69,61,112,399,450,195,111,159,244,68,268,97,108,372,308,522,366,79,250,69,115,158,233,109,250,443,157,147,155],"yaxis":"y","type":"scatter"},{"hovertemplate":"venue=Voice of the Negro\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Voice of the Negro","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Voice of the Negro","orientation":"v","showlegend":true,"x":[1904,1904,1904,1904,1904,1904,1904,1904,1904,1904,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,19 ...

# %% [markdown]
# **📝 Exercise 10**: We will filter `poems_themes` for only themes that have more than 40 rows.
#
# Now, using this new `poems_themes_filtered`, make a plot with different facets for the scatter plot considering different themes.

# %%
# Group by 'themes' and count occurrences, then filter.
theme_counts = poems_themes.groupby('themes').size()
themes_to_keep = theme_counts[theme_counts > 40].index.tolist()
poems_themes_filtered = poems_themes[poems_themes['themes'].isin(themes_to_keep)]

# %%
fig = px.scatter(poems_themes_filtered, x='year', y='Poem_Length', color='venue', facet_col='themes', title='Poem Length by Year for Themes with More Than 40 Rows')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fc5f3c72-7e36-4265-90b1-33646222f75e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc5f3c72-7e36-4265-90b1-33646222f75e")) {                    Plotly.newPlot(                        "fc5f3c72-7e36-4265-90b1-33646222f75e",                        [{"hovertemplate":"venue=Colored American \u003cbr\u003ethemes=Slavery\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Colored American ","orientation":"v","showlegend":true,"x":[1900,1900,1901],"xaxis":"x","y":[835,280,451],"yaxis":"y","type":"scatter"},{"hovertemplate":"venue=Colored American \u003cbr\u003ethemes=Progress and Racial Uplift\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Colored American ","orientation":"v","showlegend":false,"x":[1900],"xaxis":"x2","y":[280],"yaxis":"y2","type":"scatter"},{"hovertemplate":"venue=Colored American \u003cbr\u003ethemes=Racism\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Colored American ","orientation":"v","showlegend":false,"x":[1900],"xaxis":"x3","y":[132],"yaxis":"y3","type":"scatter"},{"hovertemplate":"venue=Colored American \u003cbr\u003ethemes=Religion\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Colored American ","orientation":"v","showlegend":false,"x":[1901],"xaxis":"x4","y":[121],"yaxis":"y4","type":"scatter"},{"hovertemplate":"venue=Colored American\u003cbr\u003ethemes=Slavery\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Colored American","orientation":"v","showlegend":true,"x":[1901],"xaxis":"x","y":[328],"yaxis":"y","type":"scatter"},{"hovertemplate":"venue=Colored American\u003cbr\u003ethemes=Progress and Racial Uplift\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Colored American","orientation":"v","showlegend":false,"x":[1905],"xaxis":"x2","y":[108],"yaxis":"y2","type":"scatter"},{"hovertemplate":"venue=Colored American\u003cbr\u003ethemes=Religion\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Colored American","orientation":"v","showlegend":false,"x":[1901,1901,1901],"xaxis":"x4","y":[366,190,118],"yaxis":"y4","type":"scatter"},{"hovertemplate":"venue=Colored American Magazine\u003cbr\u003ethemes=Slavery\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American Magazine","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Colored American Magazine","orientation":"v","showlegend":true,"x":[1903],"xaxis":"x","y":[883],"yaxis":"y","type":"scatter"},{"hovertemplate":"venue=Colored American Magazine\u003cbr\u003ethemes=Progress and Racial Uplift\u003cbr\u003eyear=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American Maga ...
